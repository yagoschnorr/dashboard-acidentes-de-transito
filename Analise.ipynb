# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from wordcloud import WordCloud, STOPWORDS

# %%
df = pd.read_csv('Dados_PRF_2022.csv', encoding = 'latin1', sep = ';')

# %%
df.head()
# Out:
#        id data_inversa dia_semana   horario  uf     br     km  \
# 0  405151   2022-01-01     sábado  01:35:00  PI  316.0    415
# 1  405158   2022-01-01     sábado  02:40:00  PR  116.0     33
# 2  405172   2022-01-01     sábado  05:22:00  MS  163.0    393
# 3  405203   2022-01-01     sábado  07:00:00  RJ  101.0    457
# 4  405207   2022-01-01     sábado  09:00:00  MG   40.0  508,3
#
#                municipio                                     causa_acidente  \
# 0            MARCOLANDIA                   Ingestão de álcool pelo condutor
# 1  CAMPINA GRANDE DO SUL                   Ingestão de álcool pelo condutor
# 2   NOVA ALVORADA DO SUL  Condutor deixou de manter distância do veículo...
# 3         ANGRA DOS REIS           Reação tardia ou ineficiente do condutor
# 4     RIBEIRAO DAS NEVES                  Acumulo de água sobre o pavimento
#
#                tipo_acidente  ... feridos_graves ilesos ignorados feridos  \
# 0           Colisão traseira  ...              0      1         0       1
# 1                 Tombamento  ...              0      0         0       1
# 2           Colisão traseira  ...              0      1         0       1
# 3            Colisão frontal  ...              1      1         0       1
# 4  Saída de leito carroçável  ...              0      3         0       0
#
#   veiculos      latitude     longitude  regional  delegacia             uop
# 0        2   -7,43280012  -40,68261908   SPRF-PI   DEL04-PI  UOP03-DEL04-PI
# 1        1    -25,114403   -48,8467554   SPRF-PR   DEL01-PR  UOP02-DEL01-PR
# 2        2    -21,228445    -54,456296   SPRF-MS   DEL02-MS  UOP01-DEL02-MS
# 3        2  -23,03149804  -44,17715297   SPRF-RJ   DEL03-RJ  UOP02-DEL03-RJ
# 4        1  -19,76061249   -44,1347544   SPRF-MG   DEL02-MG  UOP01-DEL02-MG
#
# [5 rows x 30 columns]

# %%
df.shape
# Out:
# (64547, 30)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64547 entries, 0 to 64546
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      64547 non-null  int64
#  1   data_inversa            64547 non-null  object
#  2   dia_semana              64547 non-null  object
#  3   horario                 64547 non-null  object
#  4   uf                      64547 non-null  object
#  5   br                      64350 non-null  float64
#  6   km                      64350 non-null  object
#  7   municipio               64547 non-null  object
#  8   causa_acidente          64547 non-null  object
#  9   tipo_acidente           64547 non-null  object
#  10  classificacao_acidente  64547 non-null  object
#  11  fase_dia                64547 non-null  object
#  12  sentido_via             64547 non-null  object
#  13  condicao_metereologica  64547 non-null  object
#  14  tipo_pista              64547 non-null  object
#  15  tracado_via             64547 non-null  object
#  16  uso_solo                64547 non-null  object
#  17  pessoas                 64547 non-null  int64
#  18  mortos                  64547 non-null  int64
#  19  feridos_leves           64547 non-null  int64
#  20  feridos_graves          64547 non-null  int64
#  21  ilesos                  64547 non-null  int64
#  22  ignorados               64547 non-null  int64
#  23  feridos                 64547 non-null  int64
#  24  veiculos                64547 non-null  int64
#  25  latitude                64547 non-null  object
#  26  longitude               64547 non-null  object
#  27  regional                64544 non-null  object
#  28  delegacia               63788 non-null  object
#  29  uop                     64499 non-null  object
# dtypes: float64(1), int64(9), object(20)
# memory usage: 14.8+ MB

# %% [markdown]
# # Tratamento

# %%
df.isnull().sum()
# Out:
# id                          0
# data_inversa                0
# dia_semana                  0
# horario                     0
# uf                          0
# br                        197
# km                        197
# municipio                   0
# causa_acidente              0
# tipo_acidente               0
# classificacao_acidente      0
# fase_dia                    0
# sentido_via                 0
# condicao_metereologica      0
# tipo_pista                  0
# tracado_via                 0
# uso_solo                    0
# pessoas                     0
# mortos                      0
# feridos_leves               0
# feridos_graves              0
# ilesos                      0
# ignorados                   0
# feridos                     0
# veiculos                    0
# latitude                    0
# longitude                   0
# regional                    3
# delegacia                 759
# uop                        48
# dtype: int64

# %%
df_nulos = df[df.isnull().any(axis=1)]
df_nulos.head()
# Out:
#          id data_inversa     dia_semana   horario  uf     br   km  municipio  \
# 49   405687   2022-01-03  segunda-feira  11:30:00  RR  174.0  503  BOA VISTA
# 207  407210   2022-01-07    sexta-feira  01:30:00  RR  174.0  318  CARACARAI
# 248  407393   2022-01-08         sábado  02:00:00  AP  210.0    2     MACAPA
# 474  408564   2022-01-14    sexta-feira  12:00:00  RR  174.0  504  BOA VISTA
# 493  408663   2022-01-14    sexta-feira  20:30:00  BA    NaN  NaN  BARREIRAS
#
#                                         causa_acidente  \
# 49   Condutor deixou de manter distância do veículo...
# 207           Reação tardia ou ineficiente do condutor
# 248                   Ingestão de álcool pelo condutor
# 474  Condutor deixou de manter distância do veículo...
# 493                      Entrada inopinada do pedestre
#
#                  tipo_acidente  ... feridos_graves ilesos ignorados feridos  \
# 49            Colisão traseira  ...              0      2         0       0
# 207         Colisão com objeto  ...              1      1         0       1
# 248         Colisão com objeto  ...              0      1         0       1
# 474           Colisão traseira  ...              0      3         0       1
# 493  Atropelamento de Pedestre  ...              0      1         0       0
#
#     veiculos     latitude     longitude  regional  delegacia             uop
# 49         2     2,794901    -60,698441   SPRF-RR        NaN  UOP01-DEL01-RR
# 207        1   1,49675231  -60,94122833   SPRF-RR        NaN  UOP01-DEL01-RR
# 248        2   0,08282017  -51,07776189   SPRF-AP        NaN  UOP01-DEL01-AP
# 474        2     2,801374    -60,694801   SPRF-RR        NaN  UOP01-DEL01-RR
# 493        1  -12,1376959    -44,921313   SPRF-BA   DEL10-BA  UOP01-DEL10-BA
#
# [5 rows x 30 columns]

# %%
df['horario'] = pd.to_datetime(df['horario'])
# Out:
# C:\Users\Yago Schnorr\AppData\Local\Temp\ipykernel_17792\1165561740.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['horario'] = pd.to_datetime(df['horario'])

# %%
df['hora'] = df['horario'].dt.hour

# %%
df = df.dropna(subset=['uop', 'br', 'km'])

# %%
df.isnull().sum()
# Out:
# id                          0
# data_inversa                0
# dia_semana                  0
# horario                     0
# uf                          0
# br                          0
# km                          0
# municipio                   0
# causa_acidente              0
# tipo_acidente               0
# classificacao_acidente      0
# fase_dia                    0
# sentido_via                 0
# condicao_metereologica      0
# tipo_pista                  0
# tracado_via                 0
# uso_solo                    0
# pessoas                     0
# mortos                      0
# feridos_leves               0
# feridos_graves              0
# ilesos                      0
# ignorados                   0
# feridos                     0
# veiculos                    0
# latitude                    0
# longitude                   0
# regional                    0
# delegacia                 734
# uop                         0
# hora                        0
# dtype: int64

# %%
vetor = df['uop'][0].split('-')

print(vetor)

'-'.join(vetor)[6:]
# Out:
# ['UOP03', 'DEL04', 'PI']
# 'DEL04-PI'

# %%
df['delegacia'] = df['delegacia'].fillna(df['uop'].apply(lambda x: '-'.join(x.split('-')[1:])))

# %%
df.query('id == 405687')
# Out:
#         id data_inversa     dia_semana             horario  uf     br   km  \
# 49  405687   2022-01-03  segunda-feira 2025-04-28 11:30:00  RR  174.0  503
#
#     municipio                                     causa_acidente  \
# 49  BOA VISTA  Condutor deixou de manter distância do veículo...
#
#        tipo_acidente  ... ilesos ignorados feridos veiculos  latitude  \
# 49  Colisão traseira  ...      2         0       0        2  2,794901
#
#      longitude regional  delegacia             uop  hora
# 49  -60,698441  SPRF-RR   DEL01-RR  UOP01-DEL01-RR    11
#
# [1 rows x 31 columns]

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df['dia_semana'].unique()
# Out:
# array(['sábado', 'domingo', 'segunda-feira', 'terça-feira',
#        'quarta-feira', 'quinta-feira', 'sexta-feira'], dtype=object)

# %%
norte = ['PA', 'AM', 'RR', 'RO', 'AC', 'AP', 'TO']
nordeste = ['MA', 'PI', 'BA', 'CE', 'RN', 'PB', 'PE', 'AL', 'SE']
centro_oeste = ['MT', 'MS', 'GO', 'DF']
sudeste = ['MG', 'ES', 'RJ', 'SP']
sul = ['PR', 'SC', 'RS']

# %%
def definir_regiao(estado):
    if estado in norte:
        return 'Norte'
    elif estado in nordeste:
        return 'Nordeste'
    elif estado in centro_oeste:
        return 'Centro Oeste'
    elif estado in sudeste:
        return 'Sudeste'
    else:
        return 'Sul'

# %%
df['regiao'] = df['uf'].apply(lambda x: definir_regiao(x))

# %% [markdown]
# ## Testes

# %%
df.query('regiao == "Norte"')['mortos'].value_counts()
# Out:
# mortos
# 0    3129
# 1     317
# 2      38
# 3       5
# 5       3
# 4       2
# Name: count, dtype: int64

# %%
df.query('regiao == "Norte"')['mortos'].sum()
# Out:
# np.int64(431)

# %%
df_filtrado = df[(df['regiao'].isin(['Norte', 'Sul'])) & (df['mortos'] > 0)]

df_mortes = df_filtrado.groupby('regiao')['mortos'].sum().reset_index()

df_mortes
# Out:
#   regiao  mortos
# 0  Norte     431
# 1    Sul    1255

# %%
sns.barplot(df_mortes,
            x='regiao',
            y='mortos',
            hue='regiao')
plt.show()

# %%
df_mortes['mortos'].sum()
# Out:
# np.int64(1686)

# %%
df_filtrado2 = df[(df['regiao']=='Norte') & (df['mortos'] > 0)]

df_mortes2 = df_filtrado2.groupby(['tipo_acidente', 'regiao'])['mortos'].value_counts().sort_values(ascending=False).reset_index()

df_mortes2
# Out:
#                      tipo_acidente regiao  mortos  count
# 0                  Colisão frontal  Norte       1     86
# 1        Atropelamento de Pedestre  Norte       1     50
# 2        Saída de leito carroçável  Norte       1     45
# 3                 Colisão traseira  Norte       1     38
# 4              Colisão transversal  Norte       1     32
# 5                       Tombamento  Norte       1     24
# 6                  Colisão frontal  Norte       2     21
# 7    Colisão lateral mesmo sentido  Norte       1      9
# 8               Colisão com objeto  Norte       1      9
# 9                 Colisão traseira  Norte       2      8
# 10  Colisão lateral sentido oposto  Norte       1      7
# 11         Atropelamento de Animal  Norte       1      6
# 12                     Capotamento  Norte       1      6
# 13    Queda de ocupante de veículo  Norte       1      5
# 14       Saída de leito carroçável  Norte       2      4
# 15                      Tombamento  Norte       2      2
# 16                 Colisão frontal  Norte       4      2
# 17                 Colisão frontal  Norte       3      2
# 18       Atropelamento de Pedestre  Norte       2      1
# 19                     Capotamento  Norte       2      1
# 20   Colisão lateral mesmo sentido  Norte       2      1
# 21  Colisão lateral sentido oposto  Norte       3      1
# 22  Colisão lateral sentido oposto  Norte       5      1
# 23                Colisão traseira  Norte       3      1
# 24                Eventos atípicos  Norte       5      1
# 25                Colisão traseira  Norte       5      1
# 26       Saída de leito carroçável  Norte       3      1

# %%
df_mortes2['mortos'].sum()
# Out:
# np.int64(57)

# %%
total = 0

for i in range(0,26):
    total += df_mortes2['mortos'][i] * df_mortes2['count'][i]

total
# Out:
# np.int64(428)

# %%
df_mortes2['mortos'] = [df_mortes2['mortos'][i] * df_mortes2['count'][i] for i in range(0,len(df_mortes2))]

df_mortes2
# Out:
#                      tipo_acidente regiao  mortos  count
# 0                  Colisão frontal  Norte      86     86
# 1        Atropelamento de Pedestre  Norte      50     50
# 2        Saída de leito carroçável  Norte      45     45
# 3                 Colisão traseira  Norte      38     38
# 4              Colisão transversal  Norte      32     32
# 5                       Tombamento  Norte      24     24
# 6                  Colisão frontal  Norte      42     21
# 7    Colisão lateral mesmo sentido  Norte       9      9
# 8               Colisão com objeto  Norte       9      9
# 9                 Colisão traseira  Norte      16      8
# 10  Colisão lateral sentido oposto  Norte       7      7
# 11         Atropelamento de Animal  Norte       6      6
# 12                     Capotamento  Norte       6      6
# 13    Queda de ocupante de veículo  Norte       5      5
# 14       Saída de leito carroçável  Norte       8      4
# 15                      Tombamento  Norte       4      2
# 16                 Colisão frontal  Norte       8      2
# 17                 Colisão frontal  Norte       6      2
# 18       Atropelamento de Pedestre  Norte       2      1
# 19                     Capotamento  Norte       2      1
# 20   Colisão lateral mesmo sentido  Norte       2      1
# 21  Colisão lateral sentido oposto  Norte       3      1
# 22  Colisão lateral sentido oposto  Norte       5      1
# 23                Colisão traseira  Norte       3      1
# 24                Eventos atípicos  Norte       5      1
# 25                Colisão traseira  Norte       5      1
# 26       Saída de leito carroçável  Norte       3      1

# %%
nordeste = df[df['regiao'] == 'Nordeste']

sns.barplot(x=nordeste['tipo_acidente'].value_counts().index, y=nordeste['tipo_acidente'].value_counts())
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=df['uf'].value_counts().index, y=df['uf'].value_counts())
plt.show()

# %%
fig, ax = plt.subplots()

plt.subplot()
sns.histplot(data=df, x=df['horario'].dt.hour, bins=24, kde=False, edgecolor='black')
ax.set_xticks(range(0, 24))
plt.show()

# %%
sns.barplot(x=df['uf'].value_counts().index, y=df['uf'].value_counts())
plt.show()

# %%
df_metereologico = df.groupby('condicao_metereologica').size().sort_values(ascending=False).reset_index(name='quantidade')
df_metereologico
# Out:
#   condicao_metereologica  quantidade
# 0              Céu Claro       39070
# 1                Nublado       10430
# 2                  Chuva        7101
# 3                    Sol        3771
# 4         Garoa/Chuvisco        2418
# 5               Ignorado         879
# 6       Nevoeiro/Neblina         555
# 7                  Vento         121
# 8                Granizo           3
# 9                   Neve           2

# %%
sns.barplot(df_metereologico, y='condicao_metereologica', x='quantidade', hue='condicao_metereologica')
plt.show()

# %%
df_filtrar = df[df['mortos'] > 0]

# %%
df_metereologico_mortes = df_filtrar.groupby(['condicao_metereologica'])['mortos'].sum().sort_values(ascending=False).reset_index(name='quantidade')
df_metereologico_mortes
# Out:
#   condicao_metereologica  quantidade
# 0              Céu Claro        3397
# 1                Nublado         883
# 2                  Chuva         532
# 3                    Sol         237
# 4         Garoa/Chuvisco         199
# 5               Ignorado         107
# 6       Nevoeiro/Neblina          71
# 7                  Vento           9

# %%
sns.barplot(df_metereologico_mortes, y='condicao_metereologica', x='quantidade', hue='condicao_metereologica')
plt.show()

# %%
acidente_pessoa = df.groupby(['feridos_graves','ilesos','feridos_leves','ignorados'])['tipo_acidente'].value_counts()
acidente_pessoa
# Out:
# feridos_graves  ilesos  feridos_leves  ignorados  tipo_acidente
# 0               0       0              0          Saída de leito carroçável       314
#                                                   Colisão com objeto              111
#                                                   Tombamento                       95
#                                                   Atropelamento de Animal          39
#                                                   Queda de ocupante de veículo     27
#                                                                                  ...
# 11              1       33             0          Saída de leito carroçável         1
#                 16      1              0          Capotamento                       1
# 14              0       3              0          Atropelamento de Pedestre         1
# 15              12      20             0          Saída de leito carroçável         1
# 31              6       23             11         Tombamento                        1
# Name: count, Length: 2256, dtype: int64

# %% [markdown]
# ## 1 Gráfico

# %%
df_regioes = df[df['regiao'].isin(df['regiao'].unique())]

# %%
df_regiao_dia_semana = df_regioes.groupby(['dia_semana', 'regiao']).size().reset_index(name='quantidade')

semana = ['domingo', 'segunda-feira', 'terça-feira', 'quarta-feira', 'quinta-feira', 'sexta-feira', 'sábado']

fig, ax = plt.subplots()

plt.subplot()
sns.barplot(df_regiao_dia_semana,
            x='dia_semana',
            y='quantidade',
            hue='regiao',
            order=semana)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 2 Gráfico

# %%
filtro = df[(df['regiao'].isin(df['regiao'].unique())) & (df['mortos'] > 0)]

df_mortes = filtro.groupby(['tipo_acidente', 'regiao'])['mortos'].value_counts().sort_values(ascending=False).reset_index()

df_mortes['mortos'] = [df_mortes['mortos'][i] * df_mortes['count'][i] for i in range(0,len(df_mortes))]

df_mortes = df_mortes.groupby(['tipo_acidente', 'regiao'])['mortos'].sum().sort_values(ascending=False).reset_index()

fig, ax = plt.subplots()

plt.subplot()
sns.barplot(df_mortes,
            x='mortos',
            y='tipo_acidente',
            hue='tipo_acidente')

plt.show()

# %% [markdown]
# ## 3 Gráfico

# %%
df_regiao = df[df['regiao'] == 'Sudeste']

df_filtrado = df_regiao.groupby(['hora', 'regiao']).value_counts().reset_index(name='quantidade')

fig, ax = plt.subplots()

plt.subplot()
sns.histplot(data=df_filtrado, x=df['horario'].dt.hour, bins=24, kde=False, edgecolor='black')
ax.set_xticks(range(0, 24))
plt.show()

# %% [markdown]
# ## 4 Gráfico

# %%
top_acidentes = df_regioes['causa_acidente'].value_counts().nlargest(10).index

df_filtrado_top = df_filtrado[df_filtrado['causa_acidente'].isin(top_acidentes)]

df_causa_horario = df_filtrado_top.groupby(['causa_acidente', 'regiao'])['horario'].value_counts().sort_values(ascending=True).reset_index(name='quantidade')

fig, ax = plt.subplots()

plt.subplot()
sns.scatterplot(df_causa_horario,
                x='horario',
                y='causa_acidente',
                hue='quantidade')

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 5 Gráfico

# %%
df_filtrado = df[(df['regiao'].isin(df['regiao'].unique())) & (df['feridos_graves'] > 0)]

top_acidentes = df_filtrado['causa_acidente'].value_counts().nlargest(10).index

df_filtrado_top = df_filtrado[df_filtrado['causa_acidente'].isin(top_acidentes)]

df_feridos = df_filtrado_top.groupby(['causa_acidente', 'regiao'])['feridos_graves'].value_counts().sort_values(ascending=False).reset_index()

df_feridos['feridos_graves'] = [df_feridos['feridos_graves'][i] * df_feridos['count'][i] for i in range(0, len(df_feridos))]

df_feridos = df_feridos.groupby(['causa_acidente', 'regiao'])['feridos_graves'].sum().sort_values(ascending=False).reset_index()

fig, ax = plt.subplots()

plt.subplot()
sns.scatterplot(df_feridos,
                x='feridos_graves',
                y='causa_acidente',
                hue='regiao')

plt.show()

# %% [markdown]
# ## 6 Gráfico

# %%
top_acidentes = df_regioes['causa_acidente'].value_counts().nlargest(10).index

df_filtrado_top = df_filtrado[df_filtrado['causa_acidente'].isin(top_acidentes)]

df_causa_condicao = df_filtrado_top.groupby(['causa_acidente', 'regiao'])['condicao_metereologica'].value_counts().sort_values(ascending=False).reset_index(name='quantidade')

fig, ax = plt.subplots()

plt.subplot()
sns.scatterplot(df_causa_condicao,
                x='causa_acidente',
                y='condicao_metereologica',
                hue='quantidade')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 7 Gráfico

# %%
excluir = ['de','na','dos','da']
stopwords = STOPWORDS.union(excluir)
palavras_nuvem = " ".join(df['causa_acidente'])  
nuvem = WordCloud(width=1000, height=500, background_color='white', stopwords=stopwords).generate(palavras_nuvem)

fig, ax = plt.subplots()

ax.imshow(nuvem, interpolation='bilinear')
plt.show()
